# %% [markdown]
# # cubic interpolation

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
for d2 in [0.1,0.33,0.4,0.5]:

    T = [0,d2,0.666,1]#evaluation parameters for interpolation points
    P_y = [1,2,1,2]
    P_x = [1,2,3,4]
    Ts = np.zeros(shape=(4,4))

    for i,j in itertools.product(range(4),range(4)):
        Ts[i][j] = T[i]**(3-j) #vandermonde matrix [t^3,t^2,t,1] for each interpolation point
    params_x = np.linalg.solve(Ts,P_x)
    params_y = np.linalg.solve(Ts,P_y)
    #print(params_x,params_y)
    res_x = []
    res_y = []
    samples = 100
    for i in range(samples+1):
        t = i/samples
        TT = np.zeros(shape=(4,1))
        for j in range(4):
            TT[j] = t**(3-j)
        res_x.append(np.dot(params_x,TT))    
        res_y.append(np.dot(params_y,TT))    
    plt.plot(res_x,res_y)#[i/20.0 for i in range(20)]    
plt.plot(P_x,P_y,'.r')
mpld3.display()
# Out:
# [ 13.72577164 -22.87612659  12.15035494   1.        ] [ 22.95761833 -35.25338017  13.29576183   1.        ]
# [ 0.10784933 -0.18866802  3.08081868  1.        ] [ 17.92950895 -26.87654993   9.94704098   1.        ]
# [-3.16663293  5.26661944  0.90001349  1.        ] [ 20.65418036 -31.41585251  11.76167214   1.        ]
# [-12.10235558  20.15353338  -5.05117779   1.        ] [ 30.08440949 -47.12661424  18.04220475   1.        ]
# <style>
#
# </style>
#
# <div id="fig_el209721203891368751585255"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el209721203891368751585255", {"plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}], "axes": [{"yscale": "linear", "lines": [{"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data01", "id": "el20972120782240"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#007F00", "xindex": 0, "data": "data02", "id": "el20972120782688"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#FF0000", "xindex": 0, "data": "data03", "id": "el20972120805808"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#00BFBF", "xindex": 0, "data": "data04", "id": "el20972120830160"}], "xlim": [0.5, 4.5], "images": [], "sharex": [], "zoomable": true, "xscale": "linear", "sharey": [], "bbox": [0.125, 0.125, 0.775, 0.775], "collections": [], "markers": [{"edgewidth": 0.5, "yindex": 1, "alpha": 1, "coordinates": "data", "zorder": 2, "facecolor": "#FF0000", "edgecolor": "#FF0000", "xindex": 0, "data": "data05", "markerpath": [[[0.0, 1.5], [0.39780465000000004, 1.5], [0.7793698061772802, 1.3419505373823626], [1.0606601717798214, 1.0606601717798214], [1.3419505373823626, 0.7793698061772802], [1.5, 0.39780465000000004], [1.5, 0.0], [1.5, -0.39780465000000004], [1.3419505373823626, -0.7793698061772802], [1.0606601717798214, -1.0606601717798214], [0.7793698061772802, -1.3419505373823626], [0.39780465000000004, -1.5], [0.0, -1.5], [-0.39780465000000004, -1.5], [-0.7793698061772802, -1.3419505373823626], [-1.0606601717798214, -1.0606601717798214], [-1.3419505373823626, -0.7793698061772802], [-1.5, -0.39780465000000004], [-1.5, 0.0], [-1.5, 0.39780465000000004], [-1.3419505373823626, 0.7793698061772802], [-1.0606601717798214, 1.0606601717798214], [-0.7793698061772802, 1.3419505373823626], [-0.39780465000000004, 1.5], [0.0, 1.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "id": "el20972118908968pts"}], "axesbg": "#FFFFFF", "ylim": [0.5, 3.5], "texts": [], "axes": [{"position": "bottom", "tickformat": null, "tickvalues": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "nticks": 9}, {"position": "left", "tickformat": null, "tickvalues": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "nticks": 7}], "axesbgalpha": null, "paths": [], "ydomain": [0.5, 3.5], "xdomain": [0.5, 4.5], "id": "el20972120078064"}], "width": 480.0, "height": 320.0, "data": {"data04": [[1.0, 1.0], [0.9514914730616916, 1.175739470456677], [0.9069410386650991, 1.3422341245220402], [0.8662760826767177, 1.4996644686530551], [0.8294239909630432, 1.6482110093066877], [0.7963121493905709, 1.7880542529399033], [0.766867943825797, 1.919374706009667], [0.7410187601352165, 2.042352874972946], [0.7186919841853252, 2.1571692662867035], [0.699815001842619, 2.264004386407907], [0.6843151989735932, 2.3630387417935212], [0.6721199614447434, 2.4544528389005125], [0.6631566751225653, 2.538427184185845], [0.6573527258735544, 2.6151422841064855], [0.654635499564206, 2.6847786451193993], [0.6549323820610166, 2.7475167736815527], [0.658170759230481, 2.8035371762499093], [0.664278016939095, 2.853020359281437], [0.673181541053354, 2.8961468292331], [0.6848087174397544, 2.933097092561864], [0.6990869319647908, 2.964051655724695], [0.7159435704949595, 2.9891910251785583], [0.7353060188967555, 3.0086957073804195], [0.7571016630366749, 3.022746208787244], [0.7812578887812136, 3.031523035855998], [0.8077020819968661, 3.0352066950436476], [0.836361628550129, 3.0339776928071567], [0.8671639143074974, 3.0280165356034914], [0.9000363251354666, 3.0175037298896186], [0.9349062469005334, 3.002619782122501], [0.971701065469192, 2.983545198759109], [1.010348166707939, 2.9604604862564017], [1.0507749 ...

# %% [markdown]
# $$\left[ {\begin{array}{cccc}
# t_0^3&t_0^2&t_0&1\\
# t_1^3&t_1^2&t_1&1\\
# t_2^3&t_2^2&t_2&1\\
# t_3^3&t_3^2&t_3&1\\
# \end{array}} \right]\left[ {\begin{array}{c}
# a_x\\
# b_x\\
# c_x\\
# d_x\\
# \end{array}} \right]=\left[ {\begin{array}{c}
# p_0^x\\
# p_1^x\\
# p_2^x\\
# p_3^x\\
# \end{array}} \right]$$

# %% [markdown]
# # Cubic Hermite interpolation

# %%
P_0 = [1,2]
P_1 = [1,4]
dp_0 = [1,1]
dp_1 = [1,1]
C_x = np.array([P_0[0],P_1[0],dp_0[0],dp_1[0]])
C_y = np.array([P_0[1],P_1[1],dp_0[1],dp_1[1]])
TT = np.array([[2,-1,1,1],[-3,3,-2 ,-1],[0,0,1,0],[1,0,0,0]])

M_x = np.dot(TT,C_x)
M_y = np.dot(TT,C_y)
res_x = []
res_y = []
samples = 100
for i in range(samples+1):
    t = i/samples
    T = np.array([t**3,t**2, t, 1])
    
    #print(TT)
    res_x.append(np.dot(T,M_x))    
    res_y.append(np.dot(T,M_y))    
    plt.plot(res_x,res_y,'b')#[i/20.0 for i in range(20)]    
plt.plot(P_0[0],P_0[1],'.r')
plt.plot(P_1[0],P_1[1],'.r')
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3436131711328555355592"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3436131711328555355592", {"plugins": [{"type": "reset"}, {"button": true, "type": "zoom", "enabled": false}, {"button": true, "type": "boxzoom", "enabled": false}], "width": 480.0, "height": 320.0, "axes": [{"xdomain": [0.8, 2.0], "axes": [{"grid": {"gridOn": false}, "tickformat": null, "tickvalues": null, "fontsize": 10.0, "position": "bottom", "scale": "linear", "nticks": 7}, {"grid": {"gridOn": false}, "tickformat": null, "tickvalues": null, "fontsize": 10.0, "position": "left", "scale": "linear", "nticks": 7}], "ylim": [2.0, 8.0], "markers": [{"edgewidth": 0.5, "markerpath": [[[0.0, 1.5], [0.39780465000000004, 1.5], [0.7793698061772802, 1.3419505373823626], [1.0606601717798214, 1.0606601717798214], [1.3419505373823626, 0.7793698061772802], [1.5, 0.39780465000000004], [1.5, 0.0], [1.5, -0.39780465000000004], [1.3419505373823626, -0.7793698061772802], [1.0606601717798214, -1.0606601717798214], [0.7793698061772802, -1.3419505373823626], [0.39780465000000004, -1.5], [0.0, -1.5], [-0.39780465000000004, -1.5], [-0.7793698061772802, -1.3419505373823626], [-1.0606601717798214, -1.0606601717798214], [-1.3419505373823626, -0.7793698061772802], [-1.5, -0.39780465000000004], [-1.5, 0.0], [-1.5, 0.39780465000000004], [-1.3419505373823626, 0.7793698061772802], [-1.0606601717798214, 1.0606601717798214], [-0.7793698061772802, 1.3419505373823626], [-0.39780465000000004, 1.5], [0.0, 1.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "xindex": 0, "facecolor": "#FF0000", "yindex": 1, "edgecolor": "#FF0000", "data": "data01", "id": "el3436132081592pts", "coordinates": "data", "zorder": 2, "alpha": 1}, {"edgewidth": 0.5, "markerpath": [[[0.0, 1.5], [0.39780465000000004, 1.5], [0.7793698061772802, 1.3419505373823626], [1.0606601717798214, 1.0606601717798214], [1.3419505373823626, 0.7793698061772802], [1.5, 0.39780465000000004], [1.5, 0.0], [1.5, -0.39780465000000004], [1.3419505373823626, -0.7793698061772802], [1.0606601717798214, -1.0606601717798214], [0.7793698061772802, -1.3419505373823626], [0.39780465000000004, -1.5], [0.0, -1.5], [-0.39780465000000004, -1.5], [-0.7793698061772802, -1.3419505373823626], [-1.0606601717798214, -1.0606601717798214], [-1.3419505373823626, -0.7793698061772802], [-1.5, -0.39780465000000004], [-1.5, 0.0], [-1.5, 0.39780465000000004], [-1.3419505373823626, 0.7793698061772802], [-1.0606601717798214, 1.0606601717798214], [-0.7793698061772802, 1.3419505373823626], [-0.39780465000000004, 1.5], [0.0, 1.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "xindex": 0, "facecolor": "#FF0000", "yindex": 2, "edgecolor": "#FF0000", "data": "data01", "id": "el3436135742856pts", "coordinates": "data", "zorder": 2, "alpha": 1}], "collections": [], "sharey": [], "axesbg": "#FFFFFF", "axesbgalpha": null, "paths": [], "lines": [{"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data01", "id": "el3436134639400", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data02", "id": "el3436134299944", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data03", "id": "el3436134302352", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data04", "id": "el3436134345448", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data05", "id": "el3436134347520", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data06", "id": "el3436134407000", "coordinates": "data", "dasharray": "10,0", "alpha": 1}, {"color": "#0000FF", "xindex": 0, "linewidth": 1.0, "zorder": 2, "yindex": 1, "data": "data07", "id": "el3436134 ...

# %% [markdown]
# # Cubic Bezier Polynomials

# %%
P_y = [1,2,1,2]
P_x = [1,1.1,3,4]

res_x = []
res_y = []
samples = 100
for i in range(samples+1):
    t = i/samples
    TT = np.array([(1-t)**3,3*t*(1-t)**2,3*t**2*(1-t),t**3])
    #print(TT)
    res_x.append(np.dot(TT,P_x))    
    res_y.append(np.dot(TT,P_y))    
    plt.plot(res_x,res_y,'b')#[i/20.0 for i in range(20)]    
plt.plot(P_x,P_y,'-r')
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el209721268735523781703899"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el209721268735523781703899", {"plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}], "axes": [{"yscale": "linear", "lines": [{"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data01", "id": "el20972119919504"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data02", "id": "el20972119919952"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data03", "id": "el20972119922360"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data04", "id": "el20972119928592"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data05", "id": "el20972119930664"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data06", "id": "el20972119998336"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data07", "id": "el20972120000408"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data08", "id": "el20972120059888"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data09", "id": "el20972132268104"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data10", "id": "el20972132270176"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data11", "id": "el20972132333752"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data12", "id": "el20972132335824"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data13", "id": "el20972132337960"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data14", "id": "el20972132340032"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data15", "id": "el20972132219288"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data16", "id": "el20972132221360"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data17", "id": "el20972132387336"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data18", "id": "el20972132389408"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data19", "id": "el20972132371064"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data20", "id": "el20972132373136"}, {"yindex": 1, "linewidth": 1.0, "alpha": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "color": "#0000FF", "xindex": 0, "data": "data21", "id": "el20972128499952"}, {" ...
